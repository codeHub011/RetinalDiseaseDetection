# %%
import tensorflow as tf 
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
import numpy as np
import os

# %%
model = tf.keras.models.load_model("Trained_eye_disease_model.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  MobilenetV3large (Functiona  (None, 1000)             5507432
#  l)
#
#  dense (Dense)               (None, 4)                 4004
#
# ...
# Total params: 5,511,436
# Trainable params: 5,487,036
# Non-trainable params: 24,400
# _________________________________________________________________

# %%
image_path = "test\DME\DME-30521-17.jpeg"
img = tf.keras.utils.load_img(image_path,target_size = (224,224))

img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image_path = "test\DME\DME-30521-17.jpeg"
img = tf.keras.utils.load_img(image_path,target_size = (224,224))
x= tf.keras.utils.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
pred = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
pred
# Out:
# array([[0.17140174, 0.5191449 , 0.07839391, 0.23105943]], dtype=float32)

# %%
class_name = ['CNV', 'DME', 'DRUSEN', 'NORMAL']
result_index = np.argmax(pred)
print("model prediction:",class_name[result_index])
# Out:
# model prediction: DME
